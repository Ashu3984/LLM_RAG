# %%
# !git clone https://github.com/Ashu3984/indic-infrex-physigen
# Out:
# Cloning into 'indic-infrex-physigen'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 127 (delta 65), reused 62 (delta 25), pack-reused 0
# Receiving objects: 100% (127/127), 1.03 MiB | 2.36 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# %cd /content/indic-infrex-physigen
# Out:
# /content/indic-infrex-physigen

# %%
# %%capture
# !pip install -r requirements.txt

# %%
# !python generate.py \
    --load_8bit \
    --base_model 'teknium/OpenHermes-2.5-Mistral-7B' \
    --lora_weights 'ashu3984/PHYSIGEN-mistral7B-small' \
    --share_gradio
# Out:
# 2023-12-22 19:13:57.766600: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-22 19:13:57.766663: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-22 19:13:57.768041: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-22 19:13:59.089702: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 1.60k/1.60k [00:00<00:00, 7.60MB/s]
# tokenizer.model: 100% 493k/493k [00:00<00:00, 17.4MB/s]
# added_tokens.json: 100% 51.0/51.0 [00:00<00:00, 303kB/s]
# ...
